# %% [markdown]
# # Support vector machines.
#
# We want to find the hyperplane whose margin is the best.
#
# we select a hyperplane. Then we get positive and negetive hyperplanes(Parrellel hperplanes which touches both the parts) and then try to maximize the distance between them.
#
# ![image.png](attachment:image.png)
#
# These points are called support vectors->
#
# ![image-2.png](attachment:image-2.png)
#
#
# **SVM's are robust to Outliers**

# %% [markdown]
# # Hard margin SVM:
#
# we first assume positive hyperplane and negetive hyperplane with the fomulaes
#
#         W^T * X + b = 1
#
#         W^T * X + b =-1
#
# so that we can maintain equal distance of the regression plane to positive and negetive planes.
#
# We tune the parameters by the decision rule:
#
#             y = +1 if W * X + b >=1
#             y = -1 if W * X + B <=-1
#
#             Y*(W * X + b )>= 1
#
# ![image.png](attachment:image.png)
#
# so we need to maximize the value of  d = 2 / |W|  and the general equation given above.
#
# we cannot find the values of W and b for non linear data with no clear margin , these cases to be solved by hard margin , but for now linear data can be seperated using hard margins.

# %% [markdown]
# # Soft margin SVM:
