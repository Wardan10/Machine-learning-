# %% [markdown]
# # Agglomerative Heirachical clustering
#
# what's the problem with k means clustering algorithm:
#
# ![image.png](attachment:image.png)
#
# Two types:
#
# 1. Agglomerative clustering.
#
# 2. Divisive clustering.

# %% [markdown]
# we create a dendogram which keeps record of how the clusters are sequentially formed based on how close they are.
#
# first all the points are seperate , then aspoints which are closed are clusterd.
#
# Algorithm:
#
# 1. Initialize the proximity matrix
# 2. Make each point a cluster.
# 3. in loop:
#
#            Merge the two closest clusters.n
#
#            Update the proximity matrix
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
#
# 1. Min: to merge the clusters locates the minimum distance of all the possible combinations of points of two clusters.
# (suseptible to noise and more spread)
#
# 2. max: makes more subclusters from two clusters but more robust to noise.
#
# 3. group average : avg of all the possible distances.
#
# 4. Ward:
#
# ![image-3.png](attachment:image-3.png)
#
# # The number of clusters is decided by:
#
# ![image-4.png](attachment:image-4.png)
#
# # doubt

# %%
import pandas as pd
import numpy as np
df=pd.read_csv(r'C:\Users\ASUS\Desktop\Ma_ler\Dsets\marketing_campaign.csv',sep='\t')
df=pd.DataFrame(df)
df.head()
# Out:
#       ID   Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 5524             1957  Graduation         Single  58138.0        0         0
# 2174             1954  Graduation         Single  46344.0        1         1
# 4141             1965  Graduation       Together  71613.0        0         0
# 6182             1984  Graduation       Together  26646.0        1         0
# 5324             1981         PhD        Married  58293.0        1         0
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  NumWebVisitsMonth  \
# 5524  04-09-2012       58       635         88  ...                  7
# 2174  08-03-2014       38        11          1  ...                  5
# 4141  21-08-2013       26       426         49  ...                  4
# 6182  10-02-2014       26        11          4  ...                  6
# 5324  19-01-2014       94       173         43  ...                  5
#
# ...

# %%
from sklearn.preprocessing import LabelEncoder
print(df.columns)
le=LabelEncoder()
df.drop(columns=['Dt_Customer'])
df['Kidhome']=df['Kidhome']+df['Teenhome']
for i in df.columns:
    if not isinstance(df[i][0], (np.int64, np.float64)):
        df[i]=le.fit_transform(df[i])
df.head()
# Out:
# Index(['ID   Year_Birth', 'Education', 'Marital_Status', 'Income', 'Kidhome',
#        'Teenhome', 'Dt_Customer', 'Recency', 'MntWines', 'MntFruits',
#        'MntMeatProducts', 'MntFishProducts', 'MntSweetProducts',
#        'MntGoldProds', 'NumDealsPurchases', 'NumWebPurchases',
#        'NumCatalogPurchases', 'NumStorePurchases', 'NumWebVisitsMonth',
#        'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'AcceptedCmp1',
#        'AcceptedCmp2', 'Complain', 'Z_CostContact', 'Z_Revenue', 'Response'],
#       dtype='object')
#       ID   Year_Birth  Education  Marital_Status   Income  Kidhome  Teenhome  \
# 5524             1957          2               4  58138.0        0         0
# 2174             1954          2               4  46344.0        1         1
# 4141             1965          2               5  71613.0        0         0
# 6182             1984          2               5  26646.0        1         0
# ...

# %% [markdown]
# # Do it at another time!
